# %% [markdown]
# ### Relax Inc Data Science Challenge

# %% [markdown]
# __Taks__ : Defining an "adopted user" as a user who has logged into the product on three separate days in at least one seven­day period, identify which factors predict future user adoption.

# %%
import pandas as pd
import numpy as np

# %%
users=pd.read_csv("users.csv")
engagement=pd.read_csv("takehome_user_engagement.csv")

# %%
users.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
engagement.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
engagement["time_stamp"]=pd.to_datetime(engagement["time_stamp"])

# %%
engagement["date"]=engagement["time_stamp"].dt.date

# %% [markdown]
# ### 1/ Determine which users have been adopted

# %%
adopted=[]
for user_id in engagement["user_id"].unique() : 
    if len(engagement[engagement["user_id"]==user_id]) < 3 :
        adopted.append(0)
    else : 
        
        logs=engagement[engagement["user_id"]==user_id]["date"]
        logs=(logs.shift(-2) - logs).dt.days
        if ((logs<8).sum()) > 1 :
            adopted.append(1)
        else : 
            adopted.append(0)

# %%
adopted=pd.DataFrame({"object_id": engagement["user_id"].unique(), "adopted": adopted})

# %%
adopted.head()
# Out:
#    object_id  adopted
# 0          1        0
# 1          2        1
# 2          3        0
# 3          4        0
# 4          5        0

# %%
adopted
# Out:
#       object_id  adopted
# 0             1        0
# 1             2        1
# 2             3        0
# 3             4        0
# 4             5        0
# ...         ...      ...
# 8818      11996        0
# 8819      11997        0
# 8820      11998        0
# 8821      11999        0
# 8822      12000        0
#
# [8823 rows x 2 columns]

# %%
users=pd.merge(users,adopted,how="right",on="object_id")

# %%
users.isna().sum()
# Out:
# object_id                        0
# creation_time                    0
# name                             0
# email                            0
# creation_source                  0
# last_session_creation_time       0
# opted_in_to_mailing_list         0
# enabled_for_marketing_drip       0
# org_id                           0
# invited_by_user_id            4047
# adopted                          0
# dtype: int64

# %%
users["invited_by_user_id"]=(users["invited_by_user_id"].fillna(0)>0)*1

# %%
users
# Out:
#       object_id        creation_time               name  \
# 0             1  2014-04-22 03:53:30     Clausen August
# 1             2  2013-11-15 03:45:04      Poole Matthew
# 2             3  2013-03-19 23:14:52  Bottrill Mitchell
# 3             4  2013-05-21 08:09:28    Clausen Nicklas
# 4             5  2013-01-17 10:14:20          Raw Grace
# ...         ...                  ...                ...
# 8818      11996  2013-09-06 06:14:15       Meier Sophia
# 8819      11997  2013-01-10 18:28:37      Fisher Amelie
# 8820      11998  2014-04-27 12:45:16        Haynes Jake
# 8821      11999  2012-05-31 11:55:59       Faber Annett
# 8822      12000  2014-01-26 08:57:12         Lima Thaís
#
#                            email     creation_source  \
# 0       AugustCClausen@yahoo.com        GUEST_INVITE
# 1         MatthewPoole@gustr.com          ORG_INVITE
# 2     MitchellBottrill@gustr.com          ORG_INVITE
# 3      NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %% [markdown]
# ### 2/ Determine features influencing user adoption

# %% [markdown]
# We will use a chi squared test on categorical features

# %%
X=users.drop(["creation_time","name","email","last_session_creation_time","object_id","adopted"],axis=1)
y=users["adopted"]

# %%
X=pd.concat([X.drop("creation_source",axis=1),pd.get_dummies(X["creation_source"])],axis=1)

# %%
chi2(X,y)[0]
# Out:
# array([4.92400693e-01, 1.08924145e-01, 4.63301115e+03, 3.24561132e+00,
#        2.28804449e+01, 1.37101555e+00, 2.74722350e+00, 6.90245294e+00,
#        2.25276914e+00])

# %%
import sklearn
from sklearn.feature_selection import chi2


import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

plt.subplots(figsize=(20,8))
plt.bar(pd.Series(chi2(X,y)[1],index=X.columns).index,pd.Series(chi2(X,y)[1],index=X.columns).values);


plt.title("chi squred test of depency between categorical features and user retention",fontsize=18);
plt.ylabel("probability of F-statistic being greater than chi squared test F-statistic",fontsize=15);

# %% [markdown]
# __Answer__ : According to the Chi squared test, factors predict future user adoption are org_id, creation_source, and signup
